# %% [markdown]
# # 🎾Хорошо настроенный LightGBM

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# Функция для имитации реалистичных пропусков в теннисных данных
def create_realistic_tennis_missing_data(tennis_df, random_state=None):
    np.random.seed(random_state)
    df = tennis_df.copy()

    # 1. Рейтинг и очки чаще отсутствуют у малоизвестных игроков
    high_rank_mask = df['Rank_1'] > 100
    df.loc[high_rank_mask & (np.random.random(len(df)) < 0.3), 'Pts_1'] = np.nan

    high_rank_mask = df['Rank_2'] > 100
    df.loc[high_rank_mask & (np.random.random(len(df)) < 0.3), 'Pts_2'] = np.nan

    # 2. Коэффициенты могут отсутствовать для некоторых матчей
    df.loc[np.random.random(len(df)) < 0.1, ['Odd_1', 'Odd_2']] = np.nan

    # 3. Счет может быть неполным для незавершенных матчей
    # Имитируем отсутствие последних сетов
    def truncate_score(score, prob_missing=0.15):
        if pd.isna(score) or np.random.random() > prob_missing:
            return score

        sets = score.split()
        if len(sets) <= 1:
            return score

        # Сохраняем только первый сет с вероятностью 0.7, иначе первые два
        n_sets = 1 if np.random.random() < 0.7 else 2
        n_sets = min(n_sets, len(sets))

        return ' '.join(sets[:n_sets])

    df['Score'] = df['Score'].apply(lambda x: truncate_score(x))

    return df

# Функция для извлечения признаков из счета матча
def extract_score_features(score):
    if pd.isna(score):
        return [0] * 6
    
    sets = score.split()
    total_sets = len(sets)
    sets_won_1 = 0
    sets_won_2 = 0
    total_games_1 = 0
    total_games_2 = 0
    
    for set_score in sets:
        games = set_score.split('-')
        if len(games) == 2:
            games_1 = int(games[0])
            games_2 = int(games[1])
            total_games_1 += games_1
            total_games_2 += games_2
            if games_1 > games_2:
                sets_won_1 += 1
            else:
                sets_won_2 += 1
    
    return [total_sets, sets_won_1, sets_won_2, 
            total_games_1, total_games_2,
            total_games_1 + total_games_2]

# Функция для создания дополнительных признаков
def create_comparison_features(df):
    features = pd.DataFrame()
    
    # Рейтинговое преимущество (чем больше разница, тем сильнее преимущество)
    features['rank_advantage'] = (df['Rank_2'] - df['Rank_1']) / (df['Rank_1'] + df['Rank_2'])
    
    # Очковое преимущество
    features['points_advantage'] = (df['Pts_1'] - df['Pts_2']) / (df['Pts_1'] + df['Pts_2'])
    
    # Преимущество по коэффициентам
    features['odds_advantage'] = (df['Odd_2'] - df['Odd_1']) / (df['Odd_1'] + df['Odd_2'])
    
    # Бинарные признаки для прямого сравнения
    features['better_rank'] = (df['Rank_1'] < df['Rank_2']).astype(int)
    features['more_points'] = (df['Pts_1'] > df['Pts_2']).astype(int)
    features['better_odds'] = (df['Odd_1'] < df['Odd_2']).astype(int)
    
    # Составной показатель преимущества
    features['overall_advantage'] = (features['better_rank'] + 
                                   features['more_points'] + 
                                   features['better_odds']) / 3
    
    # Добавляем квадраты и взаимодействия признаков
    features['rank_points_interaction'] = features['rank_advantage'] * features['points_advantage']
    features['rank_odds_interaction'] = features['rank_advantage'] * features['odds_advantage']
    features['points_odds_interaction'] = features['points_advantage'] * features['odds_advantage']
    
    return features

# Обновленная функция подготовки данных
def prepare_data(df):
    df = df.copy()
    
    # Конвертируем дату в datetime
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Заменяем отрицательные значения на NaN
    numeric_columns = ['Rank_1', 'Rank_2', 'Pts_1', 'Pts_2', 'Odd_1', 'Odd_2']
    for col in numeric_columns:
        df.loc[df[col] < 0, col] = np.nan
    
    # Извлекаем признаки из счета
    score_features = df['Score'].apply(extract_score_features)
    score_features_df = pd.DataFrame(score_features.tolist(), 
                                   columns=['total_sets', 'sets_won_1', 'sets_won_2',
                                          'total_games_1', 'total_games_2', 'total_games'])
    
    # Создаем признак результата
    df['target'] = (df['Winner'] == df['Player_1']).astype(int)
    
    # Кодируем категориальные признаки
    le = LabelEncoder()
    categorical_columns = ['Series', 'Court', 'Surface', 'Round']
    for col in categorical_columns:
        df[col + '_encoded'] = le.fit_transform(df[col])
    
    # Добавляем новые признаки сравнения
    comparison_features = create_comparison_features(df)
    
    # Объединяем все признаки
    features = pd.concat([
        df[['Rank_1', 'Rank_2', 'Pts_1', 'Pts_2', 'Odd_1', 'Odd_2']],
        df[[col + '_encoded' for col in categorical_columns]],
        score_features_df,
        comparison_features
    ], axis=1)
    
    return features, df['target']

# Функция для обучения модели с настроенными параметрами
def train_model(df_train):
    X, y = prepare_data(df_train)

    # Заполняем пропущенные значения
    X = X.fillna(X.mean())
    
    # Градиентный бустинг
    model = LGBMClassifier(
        n_estimators=300,  # Увеличенное количество деревьев
        learning_rate=0.03,  # Уменьшенная скорость обучения для лучшей обобщающей способности
        max_depth=10,  # Увеличенная глубина дерева
        num_leaves=40,  # Увеличенное количество листьев
        min_child_samples=15,  # Минимальное количество образцов в листе
        subsample=0.85,  # Доля выборки для тренировки каждого дерева
        colsample_bytree=0.85,  # Доля признаков для тренировки каждого дерева
        reg_alpha=0.1,  # L1 регуляризация
        reg_lambda=0.3,  # L2 регуляризация
        random_state=32,
        boosting_type='gbdt',  # Gradient Boosting Decision Tree
        objective='binary',
        class_weight='balanced',  # Балансируем веса классов
        verbose=-1
    )
    model.fit(X, y)
    
    return model

# Функции get_predictions, create_results_table и display_results остаются без изменений
def get_predictions(model, df_test):
    X_test, y_test = prepare_data(df_test)
    X_test = X_test.fillna(X_test.mean())
    probabilities = model.predict_proba(X_test)
    return probabilities

# Функция для создания таблицы результатов
def create_results_table(df_test, predictions):
    results = pd.DataFrame({
        'Player_1': df_test['Player_1'],
        'Player_1_Prediction': predictions[:, 1] * 100,
        'Player_2': df_test['Player_2'],
        'Player_2_Prediction': predictions[:, 0] * 100,
        'Winner': df_test['Winner'],
        'Rank_1': df_test['Rank_1'],
        'Rank_2': df_test['Rank_2'],
        'Pts_1': df_test['Pts_1'],
        'Pts_2': df_test['Pts_2'],
        'Odd_1': df_test['Odd_1'],
        'Odd_2': df_test['Odd_2'],
        'Score': df_test['Score']
    })
    
    # Определяем, кого модель прогнозирует победителем
    results['predicted_winner'] = np.where(predictions[:, 1] > predictions[:, 0], 
                                         df_test['Player_1'], 
                                         df_test['Player_2'])
    
    # Определяем, было ли предсказание верным
    results['correct_prediction'] = (results['predicted_winner'] == df_test['Winner'])
    
    # Добавляем уверенность в прогнозе - максимальная из двух вероятностей
    results['confidence'] = np.maximum(predictions[:, 0], predictions[:, 1]) * 100
    
    return results

# Функция для отображения результатов
def display_results(results):
    styled_results = results.style.format({
        'Player_1_Prediction': '{:.2f}%',
        'Player_2_Prediction': '{:.2f}%',
        'Rank_1': '{:.0f}',
        'Rank_2': '{:.0f}',
        'Pts_1': '{:.0f}',
        'Pts_2': '{:.0f}',
        'Odd_1': '{:.2f}',
        'Odd_2': '{:.2f}'
    }).apply(lambda x: ['background-color: #90EE90' if x['correct_prediction'] 
                       else 'background-color: #FFB6C6' for i in range(len(x))], axis=1)
    
    display(styled_results.hide(axis='columns', subset=['correct_prediction']))

# Функция для оценки и вывода метрик
def display_metrics(model, df_test, predictions, results):
    # Истинные значения (1 - если победил первый игрок, 0 - если второй)
    y_true = (df_test['Winner'] == df_test['Player_1']).astype(int)
    
    # Предсказанные вероятности победы первого игрока
    y_pred_proba = predictions[:, 1]
    
    # Предсказанные бинарные метки
    y_pred = (y_pred_proba > 0.5).astype(int)
    
    # Расчет метрик
    accuracy = accuracy_score(y_true, y_pred) * 100
    precision = precision_score(y_true, y_pred) * 100
    recall = recall_score(y_true, y_pred) * 100
    f1 = f1_score(y_true, y_pred) * 100
    roc_auc = roc_auc_score(y_true, y_pred_proba) * 100
    entropy_loss = log_loss(y_true, y_pred_proba)
    
    # Матрица ошибок
    cm = confusion_matrix(y_true, y_pred)
    tn, fp, fn, tp = cm.ravel()
    
    # Выводим метрики
    print(f"\nМетрики качества модели:")
    print(f"Accuracy (Точность): {accuracy:.2f}%")
    print(f"Precision (Точность по положительному классу): {precision:.2f}%")
    print(f"Recall (Полнота): {recall:.2f}%")
    print(f"F1-score (F-мера): {f1:.2f}%")
    print(f"ROC AUC: {roc_auc:.2f}%")
    print(f"Log Loss: {entropy_loss:.4f}")
    
    # Анализ ошибок
    print("\nМатрица ошибок (Confusion Matrix):")
    print(f"True Negative: {tn} (Правильно предсказанные победы второго игрока)")
    print(f"False Positive: {fp} (Неправильно предсказанные победы первого игрока)")
    print(f"False Negative: {fn} (Неправильно предсказанные победы второго игрока)")
    print(f"True Positive: {tp} (Правильно предсказанные победы первого игрока)")
    
    # Расчет метрик по уверенности прогноза
    confidence_bins = [50, 60, 70, 80, 90, 100]
    print("\nТочность предсказаний по уровню уверенности:")
    
    for i in range(len(confidence_bins)-1):
        low = confidence_bins[i]
        high = confidence_bins[i+1]
        
        # Фильтруем предсказания по уровню уверенности
        confident_preds = results[(results['confidence'] >= low) & (results['confidence'] < high)]
        
        if len(confident_preds) > 0:
            bin_accuracy = (confident_preds['correct_prediction'].sum() / len(confident_preds)) * 100
            print(f"Уверенность {low}%-{high}%: {bin_accuracy:.2f}% точность ({len(confident_preds)} матчей)")
        else:
            print(f"Уверенность {low}%-{high}%: нет матчей")
    
    # Выводим важность признаков
    feature_names = (
        ['Rank_1', 'Rank_2', 'Pts_1', 'Pts_2', 'Odd_1', 'Odd_2'] +
        ['Series_encoded', 'Court_encoded', 'Surface_encoded', 'Round_encoded'] +
        ['total_sets', 'sets_won_1', 'sets_won_2', 'total_games_1', 'total_games_2', 'total_games'] +
        ['rank_advantage', 'points_advantage', 'odds_advantage', 'better_rank', 'more_points', 'better_odds', 'overall_advantage', 
         'rank_points_interaction', 'rank_odds_interaction', 'points_odds_interaction']
    )

    # Получаем важность признаков и нормализуем их
    importances = model.feature_importances_
    # Нормализуем важности, чтобы сумма была равна 1
    normalized_importances = importances / importances.sum()
    
    feature_importance = pd.DataFrame({
        'Feature': feature_names,
        'Importance': normalized_importances
    }).sort_values('Importance', ascending=False)
    
    print("\nВажность признаков:")
    print(feature_importance.head(10).to_string(float_format=lambda x: '{:.4f}'.format(x)))

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Обучение модели на большой выборке без пропущенных значений

# %%
df_train = pd.read_csv('atp_tennis.csv')

# Обучаем модель
model = train_model(df_train)
print(f"Размер тренировочного набора: {len(df_train)}")
# Out:
# Размер тренировочного набора: 64018

# %% [markdown]
# ### Тестирование на выборке без пропущенных значений

# %%
df_test = pd.read_csv('atp_tennis_test_minus_1_set_47967_big.csv')

# Получаем предсказания
predictions = get_predictions(model, df_test)

# Создаем таблицу результатов
results = create_results_table(df_test, predictions)

# Отображаем результаты
display_results(results)

# Отображаем подробные метрики качества модели
display_metrics(model, df_test, predictions, results)
# Out:
# <style type="text/css">
# #T_86e75_row0_col0, #T_86e75_row0_col1, #T_86e75_row0_col2, #T_86e75_row0_col3, #T_86e75_row0_col4, #T_86e75_row0_col5, #T_86e75_row0_col6, #T_86e75_row0_col7, #T_86e75_row0_col8, #T_86e75_row0_col9, #T_86e75_row0_col10, #T_86e75_row0_col11, #T_86e75_row0_col12, #T_86e75_row0_col14, #T_86e75_row1_col0, #T_86e75_row1_col1, #T_86e75_row1_col2, #T_86e75_row1_col3, #T_86e75_row1_col4, #T_86e75_row1_col5, #T_86e75_row1_col6, #T_86e75_row1_col7, #T_86e75_row1_col8, #T_86e75_row1_col9, #T_86e75_row1_col10, #T_86e75_row1_col11, #T_86e75_row1_col12, #T_86e75_row1_col14, #T_86e75_row3_col0, #T_86e75_row3_col1, #T_86e75_row3_col2, #T_86e75_row3_col3, #T_86e75_row3_col4, #T_86e75_row3_col5, #T_86e75_row3_col6, #T_86e75_row3_col7, #T_86e75_row3_col8, #T_86e75_row3_col9, #T_86e75_row3_col10, #T_86e75_row3_col11, #T_86e75_row3_col12, #T_86e75_row3_col14, #T_86e75_row4_col0, #T_86e75_row4_col1, #T_86e75_row4_col2, #T_86e75_row4_col3, #T_86e75_row4_col4, #T_86e75_row4_col5, #T_86e75_row4_col6, #T_86e75_row4_col7, #T_86e75_row4_col8, #T_86e75_row4_col9, #T_86e75_row4_col10, #T_86e75_row4_col11, #T_86e75_row4_col12, #T_86e75_row4_col14, #T_86e75_row5_col0, #T_86e75_row5_col1, #T_86e75_row5_col2, #T_86e75_row5_col3, #T_86e75_row5_col4, #T_86e75_row5_col5, #T_86e75_row5_col6, #T_86e75_row5_col7, #T_86e75_row5_col8, #T_86e75_row5_col9, #T_86e75_row5_col10, #T_86e75_row5_col11, #T_86e75_row5_col12, #T_86e75_row5_col14, #T_86e75_row6_col0, #T_86e75_row6_col1, #T_86e75_row6_col2, #T_86e75_row6_col3, #T_86e75_row6_col4, #T_86e75_row6_col5, #T_86e75_row6_col6, #T_86e75_row6_col7, #T_86e75_row6_col8, #T_86e75_row6_col9, #T_86e75_row6_col10, #T_86e75_row6_col11, #T_86e75_row6_col12, #T_86e75_row6_col14, #T_86e75_row7_col0, #T_86e75_row7_col1, #T_86e75_row7_col2, #T_86e75_row7_col3, #T_86e75_row7_col4, #T_86e75_row7_col5, #T_86e75_row7_col6, #T_86e75_row7_col7, #T_86e75_row7_col8, #T_86e75_row7_col9, #T_86e75_row7_col10, #T_86e75_row7_col11, #T_86e75_row7_col12, #T_86e75_row7_col14, #T_86e75_row8_col0, #T_86e75_row8_col1, #T_86e75_row8_col2, #T_86e75_row8_col3, #T_86e75_row8_col4, #T_86e75_row8_col5, #T_86e75_row8_col6, #T_86e75_row8_col7, #T_86e75_row8_col8, #T_86e75_row8_col9, #T_86e75_row8_col10, #T_86e75_row8_col11, #T_86e75_row8_col12, #T_86e75_row8_col14, #T_86e75_row9_col0, #T_86e75_row9_col1, #T_86e75_row9_col2, #T_86e75_row9_col3, #T_86e75_row9_col4, #T_86e75_row9_col5, #T_86e75_row9_col6, #T_86e75_row9_col7, #T_86e75_row9_col8, #T_86e75_row9_col9, #T_86e75_row9_col10, #T_86e75_row9_col11, #T_86e75_row9_col12, #T_86e75_row9_col14, #T_86e75_row11_col0, #T_86e75_row11_col1, #T_86e75_row11_col2, #T_86e75_row11_col3, #T_86e75_row11_col4, #T_86e75_row11_col5, #T_86e75_row11_col6, #T_86e75_row11_col7, #T_86e75_row11_col8, #T_86e75_row11_col9, #T_86e75_row11_col10, #T_86e75_row11_col11, #T_86e75_row11_col12, #T_86e75_row11_col14, #T_86e75_row12_col0, #T_86e75_row12_col1, #T_86e75_row12_col2, #T_86e75_row12_col3, #T_86e75_row12_col4, #T_86e75_row12_col5, #T_86e75_row12_col6, #T_86e75_row12_col7, #T_86e75_row12_col8, #T_86e75_row12_col9, #T_86e75_row12_col10, #T_86e75_row12_col11, #T_86e75_row12_col12, #T_86e75_row12_col14, #T_86e75_row13_col0, #T_86e75_row13_col1, #T_86e75_row13_col2, #T_86e75_row13_col3, #T_86e75_row13_col4, #T_86e75_row13_col5, #T_86e75_row13_col6, #T_86e75_row13_col7, #T_86e75_row13_col8, #T_86e75_row13_col9, #T_86e75_row13_col10, #T_86e75_row13_col11, #T_86e75_row13_col12, #T_86e75_row13_col14, #T_86e75_row15_col0, #T_86e75_row15_col1, #T_86e75_row15_col2, #T_86e75_row15_col3, #T_86e75_row15_col4, #T_86e75_row15_col5, #T_86e75_row15_col6, #T_86e75_row15_col7, #T_86e75_row15_col8, #T_86e75_row15_col9, #T_86e75_row15_col10, #T_86e75_row15_col11, #T_86e75_row15_col12, #T_86e75_row15_col14, #T_86e75_row17_col0, #T_86e75_row17_col1, #T_86e75_row17_col2, #T_86e75_row17_col3, #T_86e75_row17_col4, #T_86e75_row17_col5, #T_86e75_row17_col6, #T_86e75_row17_col7, #T_86e75_row17_col8, #T_86e75_row17_col9, #T_86e75_row17_col10, #T_86e75_row17_col11 ...
# Метрики качества модели:
# Accuracy (Точность): 91.06%
# Precision (Точность по положительному классу): 85.71%
# Recall (Полнота): 98.36%
# F1-score (F-мера): 91.60%
# ROC AUC: 99.21%
# Log Loss: 0.1309
#
# Матрица ошибок (Confusion Matrix):
# True Negative: 52 (Правильно предсказанные победы второго игрока)
# False Positive: 10 (Неправильно предсказанные победы первого игрока)
# False Negative: 1 (Неправильно предсказанные победы второго игрока)
# True Positive: 60 (Правильно предсказанные победы первого игрока)
#
# Точность предсказаний по уровню уверенности:
# Уверенность 50%-60%: 40.00% точность (10 матчей)
# Уверенность 60%-70%: 55.56% точность (9 матчей)
# Уверенность 70%-80%: 75.00% точность (4 матчей)
# Уверенность 80%-90%: нет матчей
# Уверенность 90%-100%: 100.00% точность (100 матчей)
#
# Важность признаков:
#                     Feature  Importance
# 3                     Pts_2      0.0728
# 12               sets_won_2      0.0683
# 24    rank_odds_interaction      0.0666
# 1                    Rank_2      0.0611
# 13            total_games_1      0.0607
# 2                     Pts_1      0.0601
# 11               sets_won_1      0.0559
# 14            total_games_2      0.0552
# 25  points_odds_interaction      0.0507
# 17         points_advantage      0.0496

# %% [markdown]
# ### Тестирование на выборке с пропущенными значениями

# %%
df_test = pd.read_csv('atp_tennis_test_minus_1_set_47967_big.csv')

# Имитируем пропущенные значения в тестовой выборке
df_test_missing = create_realistic_tennis_missing_data(df_test, random_state=32)

# Получаем предсказания
predictions = get_predictions(model, df_test_missing)
    
# Создаем таблицу результатов
results = create_results_table(df_test_missing, predictions)
    
# Отображаем результаты
display_results(results)
    
# Отображаем подробные метрики качества модели
display_metrics(model, df_test_missing, predictions, results)
# Out:
# <style type="text/css">
# #T_589eb_row0_col0, #T_589eb_row0_col1, #T_589eb_row0_col2, #T_589eb_row0_col3, #T_589eb_row0_col4, #T_589eb_row0_col5, #T_589eb_row0_col6, #T_589eb_row0_col7, #T_589eb_row0_col8, #T_589eb_row0_col9, #T_589eb_row0_col10, #T_589eb_row0_col11, #T_589eb_row0_col12, #T_589eb_row0_col14, #T_589eb_row1_col0, #T_589eb_row1_col1, #T_589eb_row1_col2, #T_589eb_row1_col3, #T_589eb_row1_col4, #T_589eb_row1_col5, #T_589eb_row1_col6, #T_589eb_row1_col7, #T_589eb_row1_col8, #T_589eb_row1_col9, #T_589eb_row1_col10, #T_589eb_row1_col11, #T_589eb_row1_col12, #T_589eb_row1_col14, #T_589eb_row3_col0, #T_589eb_row3_col1, #T_589eb_row3_col2, #T_589eb_row3_col3, #T_589eb_row3_col4, #T_589eb_row3_col5, #T_589eb_row3_col6, #T_589eb_row3_col7, #T_589eb_row3_col8, #T_589eb_row3_col9, #T_589eb_row3_col10, #T_589eb_row3_col11, #T_589eb_row3_col12, #T_589eb_row3_col14, #T_589eb_row4_col0, #T_589eb_row4_col1, #T_589eb_row4_col2, #T_589eb_row4_col3, #T_589eb_row4_col4, #T_589eb_row4_col5, #T_589eb_row4_col6, #T_589eb_row4_col7, #T_589eb_row4_col8, #T_589eb_row4_col9, #T_589eb_row4_col10, #T_589eb_row4_col11, #T_589eb_row4_col12, #T_589eb_row4_col14, #T_589eb_row5_col0, #T_589eb_row5_col1, #T_589eb_row5_col2, #T_589eb_row5_col3, #T_589eb_row5_col4, #T_589eb_row5_col5, #T_589eb_row5_col6, #T_589eb_row5_col7, #T_589eb_row5_col8, #T_589eb_row5_col9, #T_589eb_row5_col10, #T_589eb_row5_col11, #T_589eb_row5_col12, #T_589eb_row5_col14, #T_589eb_row6_col0, #T_589eb_row6_col1, #T_589eb_row6_col2, #T_589eb_row6_col3, #T_589eb_row6_col4, #T_589eb_row6_col5, #T_589eb_row6_col6, #T_589eb_row6_col7, #T_589eb_row6_col8, #T_589eb_row6_col9, #T_589eb_row6_col10, #T_589eb_row6_col11, #T_589eb_row6_col12, #T_589eb_row6_col14, #T_589eb_row8_col0, #T_589eb_row8_col1, #T_589eb_row8_col2, #T_589eb_row8_col3, #T_589eb_row8_col4, #T_589eb_row8_col5, #T_589eb_row8_col6, #T_589eb_row8_col7, #T_589eb_row8_col8, #T_589eb_row8_col9, #T_589eb_row8_col10, #T_589eb_row8_col11, #T_589eb_row8_col12, #T_589eb_row8_col14, #T_589eb_row9_col0, #T_589eb_row9_col1, #T_589eb_row9_col2, #T_589eb_row9_col3, #T_589eb_row9_col4, #T_589eb_row9_col5, #T_589eb_row9_col6, #T_589eb_row9_col7, #T_589eb_row9_col8, #T_589eb_row9_col9, #T_589eb_row9_col10, #T_589eb_row9_col11, #T_589eb_row9_col12, #T_589eb_row9_col14, #T_589eb_row11_col0, #T_589eb_row11_col1, #T_589eb_row11_col2, #T_589eb_row11_col3, #T_589eb_row11_col4, #T_589eb_row11_col5, #T_589eb_row11_col6, #T_589eb_row11_col7, #T_589eb_row11_col8, #T_589eb_row11_col9, #T_589eb_row11_col10, #T_589eb_row11_col11, #T_589eb_row11_col12, #T_589eb_row11_col14, #T_589eb_row12_col0, #T_589eb_row12_col1, #T_589eb_row12_col2, #T_589eb_row12_col3, #T_589eb_row12_col4, #T_589eb_row12_col5, #T_589eb_row12_col6, #T_589eb_row12_col7, #T_589eb_row12_col8, #T_589eb_row12_col9, #T_589eb_row12_col10, #T_589eb_row12_col11, #T_589eb_row12_col12, #T_589eb_row12_col14, #T_589eb_row13_col0, #T_589eb_row13_col1, #T_589eb_row13_col2, #T_589eb_row13_col3, #T_589eb_row13_col4, #T_589eb_row13_col5, #T_589eb_row13_col6, #T_589eb_row13_col7, #T_589eb_row13_col8, #T_589eb_row13_col9, #T_589eb_row13_col10, #T_589eb_row13_col11, #T_589eb_row13_col12, #T_589eb_row13_col14, #T_589eb_row15_col0, #T_589eb_row15_col1, #T_589eb_row15_col2, #T_589eb_row15_col3, #T_589eb_row15_col4, #T_589eb_row15_col5, #T_589eb_row15_col6, #T_589eb_row15_col7, #T_589eb_row15_col8, #T_589eb_row15_col9, #T_589eb_row15_col10, #T_589eb_row15_col11, #T_589eb_row15_col12, #T_589eb_row15_col14, #T_589eb_row17_col0, #T_589eb_row17_col1, #T_589eb_row17_col2, #T_589eb_row17_col3, #T_589eb_row17_col4, #T_589eb_row17_col5, #T_589eb_row17_col6, #T_589eb_row17_col7, #T_589eb_row17_col8, #T_589eb_row17_col9, #T_589eb_row17_col10, #T_589eb_row17_col11, #T_589eb_row17_col12, #T_589eb_row17_col14, #T_589eb_row18_col0, #T_589eb_row18_col1, #T_589eb_row18_col2, #T_589eb_row18_col3, #T_589eb_row18_col4, #T_589eb_row18_col5, #T_589eb_row18_col6, #T_589eb_row18_col7, #T_589eb_row18_col8, #T_589eb_row18_col9, #T_589eb_row18_col10, #T_589 ...
# Метрики качества модели:
# Accuracy (Точность): 88.62%
# Precision (Точность по положительному классу): 83.10%
# Recall (Полнота): 96.72%
# F1-score (F-мера): 89.39%
# ROC AUC: 98.57%
# Log Loss: 0.1532
#
# Матрица ошибок (Confusion Matrix):
# True Negative: 50 (Правильно предсказанные победы второго игрока)
# False Positive: 12 (Неправильно предсказанные победы первого игрока)
# False Negative: 2 (Неправильно предсказанные победы второго игрока)
# True Positive: 59 (Правильно предсказанные победы первого игрока)
#
# Точность предсказаний по уровню уверенности:
# Уверенность 50%-60%: 36.36% точность (11 матчей)
# Уверенность 60%-70%: 33.33% точность (6 матчей)
# Уверенность 70%-80%: 60.00% точность (5 матчей)
# Уверенность 80%-90%: 0.00% точность (1 матчей)
# Уверенность 90%-100%: 100.00% точность (100 матчей)
#
# Важность признаков:
#                     Feature  Importance
# 3                     Pts_2      0.0728
# 12               sets_won_2      0.0683
# 24    rank_odds_interaction      0.0666
# 1                    Rank_2      0.0611
# 13            total_games_1      0.0607
# 2                     Pts_1      0.0601
# 11               sets_won_1      0.0559
# 14            total_games_2      0.0552
# 25  points_odds_interaction      0.0507
# 17         points_advantage      0.0496

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Обучение модели на большой выборке с пропущенными значениями

# %%
df_train = pd.read_csv('atp_tennis.csv')

# Имитируем пропущенные значения в обучающей выборке
df_train_missing = create_realistic_tennis_missing_data(df_train, random_state=32)

# Обучаем модель
model = train_model(df_train_missing)
print(f"Размер тренировочного набора: {len(df_train)}")
# Out:
# Размер тренировочного набора: 64018

# %% [markdown]
# ### Тестирование на выборке без пропущенных значений

# %%
df_test = pd.read_csv('atp_tennis_test_minus_1_set_47967_big.csv')

# Получаем предсказания
predictions = get_predictions(model, df_test)
    
# Создаем таблицу результатов
results = create_results_table(df_test, predictions)
    
# Отображаем результаты
display_results(results)
    
# Отображаем подробные метрики качества модели
display_metrics(model, df_test, predictions, results)
# Out:
# <style type="text/css">
# #T_9ef22_row0_col0, #T_9ef22_row0_col1, #T_9ef22_row0_col2, #T_9ef22_row0_col3, #T_9ef22_row0_col4, #T_9ef22_row0_col5, #T_9ef22_row0_col6, #T_9ef22_row0_col7, #T_9ef22_row0_col8, #T_9ef22_row0_col9, #T_9ef22_row0_col10, #T_9ef22_row0_col11, #T_9ef22_row0_col12, #T_9ef22_row0_col14, #T_9ef22_row2_col0, #T_9ef22_row2_col1, #T_9ef22_row2_col2, #T_9ef22_row2_col3, #T_9ef22_row2_col4, #T_9ef22_row2_col5, #T_9ef22_row2_col6, #T_9ef22_row2_col7, #T_9ef22_row2_col8, #T_9ef22_row2_col9, #T_9ef22_row2_col10, #T_9ef22_row2_col11, #T_9ef22_row2_col12, #T_9ef22_row2_col14, #T_9ef22_row3_col0, #T_9ef22_row3_col1, #T_9ef22_row3_col2, #T_9ef22_row3_col3, #T_9ef22_row3_col4, #T_9ef22_row3_col5, #T_9ef22_row3_col6, #T_9ef22_row3_col7, #T_9ef22_row3_col8, #T_9ef22_row3_col9, #T_9ef22_row3_col10, #T_9ef22_row3_col11, #T_9ef22_row3_col12, #T_9ef22_row3_col14, #T_9ef22_row4_col0, #T_9ef22_row4_col1, #T_9ef22_row4_col2, #T_9ef22_row4_col3, #T_9ef22_row4_col4, #T_9ef22_row4_col5, #T_9ef22_row4_col6, #T_9ef22_row4_col7, #T_9ef22_row4_col8, #T_9ef22_row4_col9, #T_9ef22_row4_col10, #T_9ef22_row4_col11, #T_9ef22_row4_col12, #T_9ef22_row4_col14, #T_9ef22_row5_col0, #T_9ef22_row5_col1, #T_9ef22_row5_col2, #T_9ef22_row5_col3, #T_9ef22_row5_col4, #T_9ef22_row5_col5, #T_9ef22_row5_col6, #T_9ef22_row5_col7, #T_9ef22_row5_col8, #T_9ef22_row5_col9, #T_9ef22_row5_col10, #T_9ef22_row5_col11, #T_9ef22_row5_col12, #T_9ef22_row5_col14, #T_9ef22_row6_col0, #T_9ef22_row6_col1, #T_9ef22_row6_col2, #T_9ef22_row6_col3, #T_9ef22_row6_col4, #T_9ef22_row6_col5, #T_9ef22_row6_col6, #T_9ef22_row6_col7, #T_9ef22_row6_col8, #T_9ef22_row6_col9, #T_9ef22_row6_col10, #T_9ef22_row6_col11, #T_9ef22_row6_col12, #T_9ef22_row6_col14, #T_9ef22_row7_col0, #T_9ef22_row7_col1, #T_9ef22_row7_col2, #T_9ef22_row7_col3, #T_9ef22_row7_col4, #T_9ef22_row7_col5, #T_9ef22_row7_col6, #T_9ef22_row7_col7, #T_9ef22_row7_col8, #T_9ef22_row7_col9, #T_9ef22_row7_col10, #T_9ef22_row7_col11, #T_9ef22_row7_col12, #T_9ef22_row7_col14, #T_9ef22_row8_col0, #T_9ef22_row8_col1, #T_9ef22_row8_col2, #T_9ef22_row8_col3, #T_9ef22_row8_col4, #T_9ef22_row8_col5, #T_9ef22_row8_col6, #T_9ef22_row8_col7, #T_9ef22_row8_col8, #T_9ef22_row8_col9, #T_9ef22_row8_col10, #T_9ef22_row8_col11, #T_9ef22_row8_col12, #T_9ef22_row8_col14, #T_9ef22_row9_col0, #T_9ef22_row9_col1, #T_9ef22_row9_col2, #T_9ef22_row9_col3, #T_9ef22_row9_col4, #T_9ef22_row9_col5, #T_9ef22_row9_col6, #T_9ef22_row9_col7, #T_9ef22_row9_col8, #T_9ef22_row9_col9, #T_9ef22_row9_col10, #T_9ef22_row9_col11, #T_9ef22_row9_col12, #T_9ef22_row9_col14, #T_9ef22_row10_col0, #T_9ef22_row10_col1, #T_9ef22_row10_col2, #T_9ef22_row10_col3, #T_9ef22_row10_col4, #T_9ef22_row10_col5, #T_9ef22_row10_col6, #T_9ef22_row10_col7, #T_9ef22_row10_col8, #T_9ef22_row10_col9, #T_9ef22_row10_col10, #T_9ef22_row10_col11, #T_9ef22_row10_col12, #T_9ef22_row10_col14, #T_9ef22_row12_col0, #T_9ef22_row12_col1, #T_9ef22_row12_col2, #T_9ef22_row12_col3, #T_9ef22_row12_col4, #T_9ef22_row12_col5, #T_9ef22_row12_col6, #T_9ef22_row12_col7, #T_9ef22_row12_col8, #T_9ef22_row12_col9, #T_9ef22_row12_col10, #T_9ef22_row12_col11, #T_9ef22_row12_col12, #T_9ef22_row12_col14, #T_9ef22_row13_col0, #T_9ef22_row13_col1, #T_9ef22_row13_col2, #T_9ef22_row13_col3, #T_9ef22_row13_col4, #T_9ef22_row13_col5, #T_9ef22_row13_col6, #T_9ef22_row13_col7, #T_9ef22_row13_col8, #T_9ef22_row13_col9, #T_9ef22_row13_col10, #T_9ef22_row13_col11, #T_9ef22_row13_col12, #T_9ef22_row13_col14, #T_9ef22_row14_col0, #T_9ef22_row14_col1, #T_9ef22_row14_col2, #T_9ef22_row14_col3, #T_9ef22_row14_col4, #T_9ef22_row14_col5, #T_9ef22_row14_col6, #T_9ef22_row14_col7, #T_9ef22_row14_col8, #T_9ef22_row14_col9, #T_9ef22_row14_col10, #T_9ef22_row14_col11, #T_9ef22_row14_col12, #T_9ef22_row14_col14, #T_9ef22_row15_col0, #T_9ef22_row15_col1, #T_9ef22_row15_col2, #T_9ef22_row15_col3, #T_9ef22_row15_col4, #T_9ef22_row15_col5, #T_9ef22_row15_col6, #T_9ef22_row15_col7, #T_9ef22_row15_col8, #T_9ef22_row15_col9, #T_9ef22_row15_col10, #T_9ef22_row15_col11 ...
# Метрики качества модели:
# Accuracy (Точность): 95.12%
# Precision (Точность по положительному классу): 100.00%
# Recall (Полнота): 90.16%
# F1-score (F-мера): 94.83%
# ROC AUC: 99.47%
# Log Loss: 0.2069
#
# Матрица ошибок (Confusion Matrix):
# True Negative: 62 (Правильно предсказанные победы второго игрока)
# False Positive: 0 (Неправильно предсказанные победы первого игрока)
# False Negative: 6 (Неправильно предсказанные победы второго игрока)
# True Positive: 55 (Правильно предсказанные победы первого игрока)
#
# Точность предсказаний по уровню уверенности:
# Уверенность 50%-60%: нет матчей
# Уверенность 60%-70%: нет матчей
# Уверенность 70%-80%: нет матчей
# Уверенность 80%-90%: нет матчей
# Уверенность 90%-100%: 95.12% точность (123 матчей)
#
# Важность признаков:
#                   Feature  Importance
# 16         rank_advantage      0.0888
# 0                  Rank_1      0.0802
# 1                  Rank_2      0.0625
# 6          Series_encoded      0.0606
# 2                   Pts_1      0.0581
# 24  rank_odds_interaction      0.0549
# 18         odds_advantage      0.0549
# 3                   Pts_2      0.0528
# 4                   Odd_1      0.0515
# 11             sets_won_1      0.0485

# %% [markdown]
# ### Тестирование на выборке с пропущенными значениями

# %%
df_test = pd.read_csv('atp_tennis_test_minus_1_set_47967_big.csv')

# Имитируем пропущенные значения в тестовой выборке
df_test_missing = create_realistic_tennis_missing_data(df_test, random_state=32)

# Получаем предсказания
predictions = get_predictions(model, df_test_missing)
    
# Создаем таблицу результатов
results = create_results_table(df_test_missing, predictions)
    
# Отображаем результаты
display_results(results)
    
# Отображаем подробные метрики качества модели
display_metrics(model, df_test_missing, predictions, results)
# Out:
# <style type="text/css">
# #T_684c4_row0_col0, #T_684c4_row0_col1, #T_684c4_row0_col2, #T_684c4_row0_col3, #T_684c4_row0_col4, #T_684c4_row0_col5, #T_684c4_row0_col6, #T_684c4_row0_col7, #T_684c4_row0_col8, #T_684c4_row0_col9, #T_684c4_row0_col10, #T_684c4_row0_col11, #T_684c4_row0_col12, #T_684c4_row0_col14, #T_684c4_row2_col0, #T_684c4_row2_col1, #T_684c4_row2_col2, #T_684c4_row2_col3, #T_684c4_row2_col4, #T_684c4_row2_col5, #T_684c4_row2_col6, #T_684c4_row2_col7, #T_684c4_row2_col8, #T_684c4_row2_col9, #T_684c4_row2_col10, #T_684c4_row2_col11, #T_684c4_row2_col12, #T_684c4_row2_col14, #T_684c4_row3_col0, #T_684c4_row3_col1, #T_684c4_row3_col2, #T_684c4_row3_col3, #T_684c4_row3_col4, #T_684c4_row3_col5, #T_684c4_row3_col6, #T_684c4_row3_col7, #T_684c4_row3_col8, #T_684c4_row3_col9, #T_684c4_row3_col10, #T_684c4_row3_col11, #T_684c4_row3_col12, #T_684c4_row3_col14, #T_684c4_row4_col0, #T_684c4_row4_col1, #T_684c4_row4_col2, #T_684c4_row4_col3, #T_684c4_row4_col4, #T_684c4_row4_col5, #T_684c4_row4_col6, #T_684c4_row4_col7, #T_684c4_row4_col8, #T_684c4_row4_col9, #T_684c4_row4_col10, #T_684c4_row4_col11, #T_684c4_row4_col12, #T_684c4_row4_col14, #T_684c4_row5_col0, #T_684c4_row5_col1, #T_684c4_row5_col2, #T_684c4_row5_col3, #T_684c4_row5_col4, #T_684c4_row5_col5, #T_684c4_row5_col6, #T_684c4_row5_col7, #T_684c4_row5_col8, #T_684c4_row5_col9, #T_684c4_row5_col10, #T_684c4_row5_col11, #T_684c4_row5_col12, #T_684c4_row5_col14, #T_684c4_row6_col0, #T_684c4_row6_col1, #T_684c4_row6_col2, #T_684c4_row6_col3, #T_684c4_row6_col4, #T_684c4_row6_col5, #T_684c4_row6_col6, #T_684c4_row6_col7, #T_684c4_row6_col8, #T_684c4_row6_col9, #T_684c4_row6_col10, #T_684c4_row6_col11, #T_684c4_row6_col12, #T_684c4_row6_col14, #T_684c4_row8_col0, #T_684c4_row8_col1, #T_684c4_row8_col2, #T_684c4_row8_col3, #T_684c4_row8_col4, #T_684c4_row8_col5, #T_684c4_row8_col6, #T_684c4_row8_col7, #T_684c4_row8_col8, #T_684c4_row8_col9, #T_684c4_row8_col10, #T_684c4_row8_col11, #T_684c4_row8_col12, #T_684c4_row8_col14, #T_684c4_row9_col0, #T_684c4_row9_col1, #T_684c4_row9_col2, #T_684c4_row9_col3, #T_684c4_row9_col4, #T_684c4_row9_col5, #T_684c4_row9_col6, #T_684c4_row9_col7, #T_684c4_row9_col8, #T_684c4_row9_col9, #T_684c4_row9_col10, #T_684c4_row9_col11, #T_684c4_row9_col12, #T_684c4_row9_col14, #T_684c4_row10_col0, #T_684c4_row10_col1, #T_684c4_row10_col2, #T_684c4_row10_col3, #T_684c4_row10_col4, #T_684c4_row10_col5, #T_684c4_row10_col6, #T_684c4_row10_col7, #T_684c4_row10_col8, #T_684c4_row10_col9, #T_684c4_row10_col10, #T_684c4_row10_col11, #T_684c4_row10_col12, #T_684c4_row10_col14, #T_684c4_row12_col0, #T_684c4_row12_col1, #T_684c4_row12_col2, #T_684c4_row12_col3, #T_684c4_row12_col4, #T_684c4_row12_col5, #T_684c4_row12_col6, #T_684c4_row12_col7, #T_684c4_row12_col8, #T_684c4_row12_col9, #T_684c4_row12_col10, #T_684c4_row12_col11, #T_684c4_row12_col12, #T_684c4_row12_col14, #T_684c4_row13_col0, #T_684c4_row13_col1, #T_684c4_row13_col2, #T_684c4_row13_col3, #T_684c4_row13_col4, #T_684c4_row13_col5, #T_684c4_row13_col6, #T_684c4_row13_col7, #T_684c4_row13_col8, #T_684c4_row13_col9, #T_684c4_row13_col10, #T_684c4_row13_col11, #T_684c4_row13_col12, #T_684c4_row13_col14, #T_684c4_row14_col0, #T_684c4_row14_col1, #T_684c4_row14_col2, #T_684c4_row14_col3, #T_684c4_row14_col4, #T_684c4_row14_col5, #T_684c4_row14_col6, #T_684c4_row14_col7, #T_684c4_row14_col8, #T_684c4_row14_col9, #T_684c4_row14_col10, #T_684c4_row14_col11, #T_684c4_row14_col12, #T_684c4_row14_col14, #T_684c4_row15_col0, #T_684c4_row15_col1, #T_684c4_row15_col2, #T_684c4_row15_col3, #T_684c4_row15_col4, #T_684c4_row15_col5, #T_684c4_row15_col6, #T_684c4_row15_col7, #T_684c4_row15_col8, #T_684c4_row15_col9, #T_684c4_row15_col10, #T_684c4_row15_col11, #T_684c4_row15_col12, #T_684c4_row15_col14, #T_684c4_row16_col0, #T_684c4_row16_col1, #T_684c4_row16_col2, #T_684c4_row16_col3, #T_684c4_row16_col4, #T_684c4_row16_col5, #T_684c4_row16_col6, #T_684c4_row16_col7, #T_684c4_row16_col8, #T_684c4_row16_col9, #T_684c4_row16_col10, #T_684 ...
# Метрики качества модели:
# Accuracy (Точность): 93.50%
# Precision (Точность по положительному классу): 98.18%
# Recall (Полнота): 88.52%
# F1-score (F-мера): 93.10%
# ROC AUC: 98.60%
# Log Loss: 0.2354
#
# Матрица ошибок (Confusion Matrix):
# True Negative: 61 (Правильно предсказанные победы второго игрока)
# False Positive: 1 (Неправильно предсказанные победы первого игрока)
# False Negative: 7 (Неправильно предсказанные победы второго игрока)
# True Positive: 54 (Правильно предсказанные победы первого игрока)
#
# Точность предсказаний по уровню уверенности:
# Уверенность 50%-60%: 0.00% точность (1 матчей)
# Уверенность 60%-70%: 100.00% точность (2 матчей)
# Уверенность 70%-80%: 0.00% точность (1 матчей)
# Уверенность 80%-90%: 100.00% точность (1 матчей)
# Уверенность 90%-100%: 94.92% точность (118 матчей)
#
# Важность признаков:
#                   Feature  Importance
# 16         rank_advantage      0.0888
# 0                  Rank_1      0.0802
# 1                  Rank_2      0.0625
# 6          Series_encoded      0.0606
# 2                   Pts_1      0.0581
# 24  rank_odds_interaction      0.0549
# 18         odds_advantage      0.0549
# 3                   Pts_2      0.0528
# 4                   Odd_1      0.0515
# 11             sets_won_1      0.0485

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Обучение модели на маленькой выборке без пропущенных значений

# %%
df_train = pd.read_csv('atp_tennis_47302_xxs.csv')

# Обучаем модель
model = train_model(df_train)
print(f"Размер тренировочного набора: {len(df_train)}")
# Out:
# Размер тренировочного набора: 50

# %% [markdown]
# ### Тестирование на выборке без пропущенных значений

# %%
df_test = pd.read_csv('atp_tennis_test_minus_1_set_47967_big.csv')

# Получаем предсказания
predictions = get_predictions(model, df_test)
    
# Создаем таблицу результатов
results = create_results_table(df_test, predictions)
    
# Отображаем результаты
display_results(results)
    
# Отображаем подробные метрики качества модели
display_metrics(model, df_test, predictions, results)
# Out:
# <style type="text/css">
# #T_1f6d0_row0_col0, #T_1f6d0_row0_col1, #T_1f6d0_row0_col2, #T_1f6d0_row0_col3, #T_1f6d0_row0_col4, #T_1f6d0_row0_col5, #T_1f6d0_row0_col6, #T_1f6d0_row0_col7, #T_1f6d0_row0_col8, #T_1f6d0_row0_col9, #T_1f6d0_row0_col10, #T_1f6d0_row0_col11, #T_1f6d0_row0_col12, #T_1f6d0_row0_col14, #T_1f6d0_row1_col0, #T_1f6d0_row1_col1, #T_1f6d0_row1_col2, #T_1f6d0_row1_col3, #T_1f6d0_row1_col4, #T_1f6d0_row1_col5, #T_1f6d0_row1_col6, #T_1f6d0_row1_col7, #T_1f6d0_row1_col8, #T_1f6d0_row1_col9, #T_1f6d0_row1_col10, #T_1f6d0_row1_col11, #T_1f6d0_row1_col12, #T_1f6d0_row1_col14, #T_1f6d0_row3_col0, #T_1f6d0_row3_col1, #T_1f6d0_row3_col2, #T_1f6d0_row3_col3, #T_1f6d0_row3_col4, #T_1f6d0_row3_col5, #T_1f6d0_row3_col6, #T_1f6d0_row3_col7, #T_1f6d0_row3_col8, #T_1f6d0_row3_col9, #T_1f6d0_row3_col10, #T_1f6d0_row3_col11, #T_1f6d0_row3_col12, #T_1f6d0_row3_col14, #T_1f6d0_row4_col0, #T_1f6d0_row4_col1, #T_1f6d0_row4_col2, #T_1f6d0_row4_col3, #T_1f6d0_row4_col4, #T_1f6d0_row4_col5, #T_1f6d0_row4_col6, #T_1f6d0_row4_col7, #T_1f6d0_row4_col8, #T_1f6d0_row4_col9, #T_1f6d0_row4_col10, #T_1f6d0_row4_col11, #T_1f6d0_row4_col12, #T_1f6d0_row4_col14, #T_1f6d0_row5_col0, #T_1f6d0_row5_col1, #T_1f6d0_row5_col2, #T_1f6d0_row5_col3, #T_1f6d0_row5_col4, #T_1f6d0_row5_col5, #T_1f6d0_row5_col6, #T_1f6d0_row5_col7, #T_1f6d0_row5_col8, #T_1f6d0_row5_col9, #T_1f6d0_row5_col10, #T_1f6d0_row5_col11, #T_1f6d0_row5_col12, #T_1f6d0_row5_col14, #T_1f6d0_row6_col0, #T_1f6d0_row6_col1, #T_1f6d0_row6_col2, #T_1f6d0_row6_col3, #T_1f6d0_row6_col4, #T_1f6d0_row6_col5, #T_1f6d0_row6_col6, #T_1f6d0_row6_col7, #T_1f6d0_row6_col8, #T_1f6d0_row6_col9, #T_1f6d0_row6_col10, #T_1f6d0_row6_col11, #T_1f6d0_row6_col12, #T_1f6d0_row6_col14, #T_1f6d0_row7_col0, #T_1f6d0_row7_col1, #T_1f6d0_row7_col2, #T_1f6d0_row7_col3, #T_1f6d0_row7_col4, #T_1f6d0_row7_col5, #T_1f6d0_row7_col6, #T_1f6d0_row7_col7, #T_1f6d0_row7_col8, #T_1f6d0_row7_col9, #T_1f6d0_row7_col10, #T_1f6d0_row7_col11, #T_1f6d0_row7_col12, #T_1f6d0_row7_col14, #T_1f6d0_row9_col0, #T_1f6d0_row9_col1, #T_1f6d0_row9_col2, #T_1f6d0_row9_col3, #T_1f6d0_row9_col4, #T_1f6d0_row9_col5, #T_1f6d0_row9_col6, #T_1f6d0_row9_col7, #T_1f6d0_row9_col8, #T_1f6d0_row9_col9, #T_1f6d0_row9_col10, #T_1f6d0_row9_col11, #T_1f6d0_row9_col12, #T_1f6d0_row9_col14, #T_1f6d0_row11_col0, #T_1f6d0_row11_col1, #T_1f6d0_row11_col2, #T_1f6d0_row11_col3, #T_1f6d0_row11_col4, #T_1f6d0_row11_col5, #T_1f6d0_row11_col6, #T_1f6d0_row11_col7, #T_1f6d0_row11_col8, #T_1f6d0_row11_col9, #T_1f6d0_row11_col10, #T_1f6d0_row11_col11, #T_1f6d0_row11_col12, #T_1f6d0_row11_col14, #T_1f6d0_row12_col0, #T_1f6d0_row12_col1, #T_1f6d0_row12_col2, #T_1f6d0_row12_col3, #T_1f6d0_row12_col4, #T_1f6d0_row12_col5, #T_1f6d0_row12_col6, #T_1f6d0_row12_col7, #T_1f6d0_row12_col8, #T_1f6d0_row12_col9, #T_1f6d0_row12_col10, #T_1f6d0_row12_col11, #T_1f6d0_row12_col12, #T_1f6d0_row12_col14, #T_1f6d0_row13_col0, #T_1f6d0_row13_col1, #T_1f6d0_row13_col2, #T_1f6d0_row13_col3, #T_1f6d0_row13_col4, #T_1f6d0_row13_col5, #T_1f6d0_row13_col6, #T_1f6d0_row13_col7, #T_1f6d0_row13_col8, #T_1f6d0_row13_col9, #T_1f6d0_row13_col10, #T_1f6d0_row13_col11, #T_1f6d0_row13_col12, #T_1f6d0_row13_col14, #T_1f6d0_row14_col0, #T_1f6d0_row14_col1, #T_1f6d0_row14_col2, #T_1f6d0_row14_col3, #T_1f6d0_row14_col4, #T_1f6d0_row14_col5, #T_1f6d0_row14_col6, #T_1f6d0_row14_col7, #T_1f6d0_row14_col8, #T_1f6d0_row14_col9, #T_1f6d0_row14_col10, #T_1f6d0_row14_col11, #T_1f6d0_row14_col12, #T_1f6d0_row14_col14, #T_1f6d0_row15_col0, #T_1f6d0_row15_col1, #T_1f6d0_row15_col2, #T_1f6d0_row15_col3, #T_1f6d0_row15_col4, #T_1f6d0_row15_col5, #T_1f6d0_row15_col6, #T_1f6d0_row15_col7, #T_1f6d0_row15_col8, #T_1f6d0_row15_col9, #T_1f6d0_row15_col10, #T_1f6d0_row15_col11, #T_1f6d0_row15_col12, #T_1f6d0_row15_col14, #T_1f6d0_row16_col0, #T_1f6d0_row16_col1, #T_1f6d0_row16_col2, #T_1f6d0_row16_col3, #T_1f6d0_row16_col4, #T_1f6d0_row16_col5, #T_1f6d0_row16_col6, #T_1f6d0_row16_col7, #T_1f6d0_row16_col8, #T_1f6d0_row16_col9, #T_1f6d0_row16_col10, #T_1f6 ...
# Метрики качества модели:
# Accuracy (Точность): 93.50%
# Precision (Точность по положительному классу): 89.55%
# Recall (Полнота): 98.36%
# F1-score (F-мера): 93.75%
# ROC AUC: 99.15%
# Log Loss: 0.1567
#
# Матрица ошибок (Confusion Matrix):
# True Negative: 55 (Правильно предсказанные победы второго игрока)
# False Positive: 7 (Неправильно предсказанные победы первого игрока)
# False Negative: 1 (Неправильно предсказанные победы второго игрока)
# True Positive: 60 (Правильно предсказанные победы первого игрока)
#
# Точность предсказаний по уровню уверенности:
# Уверенность 50%-60%: нет матчей
# Уверенность 60%-70%: 66.67% точность (9 матчей)
# Уверенность 70%-80%: 64.29% точность (14 матчей)
# Уверенность 80%-90%: 100.00% точность (9 матчей)
# Уверенность 90%-100%: 100.00% точность (91 матчей)
#
# Важность признаков:
#            Feature  Importance
# 11      sets_won_1      0.3455
# 12      sets_won_2      0.3090
# 4            Odd_1      0.1095
# 3            Pts_2      0.0560
# 0           Rank_1      0.0511
# 16  rank_advantage      0.0365
# 13   total_games_1      0.0292
# 2            Pts_1      0.0146
# 14   total_games_2      0.0146
# 5            Odd_2      0.0122

# %% [markdown]
# ### Тестирование на выборке с пропущенными значениями

# %%
df_test = pd.read_csv('atp_tennis_test_minus_1_set_47967_big.csv')

# Имитируем пропущенные значения в тестовой выборке
df_test_missing = create_realistic_tennis_missing_data(df_test, random_state=32)

# Получаем предсказания
predictions = get_predictions(model, df_test_missing)
    
# Создаем таблицу результатов
results = create_results_table(df_test_missing, predictions)
    
# Отображаем результаты
display_results(results)
    
# Отображаем подробные метрики качества модели
display_metrics(model, df_test_missing, predictions, results)
# Out:
# <style type="text/css">
# #T_89cc9_row0_col0, #T_89cc9_row0_col1, #T_89cc9_row0_col2, #T_89cc9_row0_col3, #T_89cc9_row0_col4, #T_89cc9_row0_col5, #T_89cc9_row0_col6, #T_89cc9_row0_col7, #T_89cc9_row0_col8, #T_89cc9_row0_col9, #T_89cc9_row0_col10, #T_89cc9_row0_col11, #T_89cc9_row0_col12, #T_89cc9_row0_col14, #T_89cc9_row1_col0, #T_89cc9_row1_col1, #T_89cc9_row1_col2, #T_89cc9_row1_col3, #T_89cc9_row1_col4, #T_89cc9_row1_col5, #T_89cc9_row1_col6, #T_89cc9_row1_col7, #T_89cc9_row1_col8, #T_89cc9_row1_col9, #T_89cc9_row1_col10, #T_89cc9_row1_col11, #T_89cc9_row1_col12, #T_89cc9_row1_col14, #T_89cc9_row3_col0, #T_89cc9_row3_col1, #T_89cc9_row3_col2, #T_89cc9_row3_col3, #T_89cc9_row3_col4, #T_89cc9_row3_col5, #T_89cc9_row3_col6, #T_89cc9_row3_col7, #T_89cc9_row3_col8, #T_89cc9_row3_col9, #T_89cc9_row3_col10, #T_89cc9_row3_col11, #T_89cc9_row3_col12, #T_89cc9_row3_col14, #T_89cc9_row4_col0, #T_89cc9_row4_col1, #T_89cc9_row4_col2, #T_89cc9_row4_col3, #T_89cc9_row4_col4, #T_89cc9_row4_col5, #T_89cc9_row4_col6, #T_89cc9_row4_col7, #T_89cc9_row4_col8, #T_89cc9_row4_col9, #T_89cc9_row4_col10, #T_89cc9_row4_col11, #T_89cc9_row4_col12, #T_89cc9_row4_col14, #T_89cc9_row5_col0, #T_89cc9_row5_col1, #T_89cc9_row5_col2, #T_89cc9_row5_col3, #T_89cc9_row5_col4, #T_89cc9_row5_col5, #T_89cc9_row5_col6, #T_89cc9_row5_col7, #T_89cc9_row5_col8, #T_89cc9_row5_col9, #T_89cc9_row5_col10, #T_89cc9_row5_col11, #T_89cc9_row5_col12, #T_89cc9_row5_col14, #T_89cc9_row6_col0, #T_89cc9_row6_col1, #T_89cc9_row6_col2, #T_89cc9_row6_col3, #T_89cc9_row6_col4, #T_89cc9_row6_col5, #T_89cc9_row6_col6, #T_89cc9_row6_col7, #T_89cc9_row6_col8, #T_89cc9_row6_col9, #T_89cc9_row6_col10, #T_89cc9_row6_col11, #T_89cc9_row6_col12, #T_89cc9_row6_col14, #T_89cc9_row7_col0, #T_89cc9_row7_col1, #T_89cc9_row7_col2, #T_89cc9_row7_col3, #T_89cc9_row7_col4, #T_89cc9_row7_col5, #T_89cc9_row7_col6, #T_89cc9_row7_col7, #T_89cc9_row7_col8, #T_89cc9_row7_col9, #T_89cc9_row7_col10, #T_89cc9_row7_col11, #T_89cc9_row7_col12, #T_89cc9_row7_col14, #T_89cc9_row11_col0, #T_89cc9_row11_col1, #T_89cc9_row11_col2, #T_89cc9_row11_col3, #T_89cc9_row11_col4, #T_89cc9_row11_col5, #T_89cc9_row11_col6, #T_89cc9_row11_col7, #T_89cc9_row11_col8, #T_89cc9_row11_col9, #T_89cc9_row11_col10, #T_89cc9_row11_col11, #T_89cc9_row11_col12, #T_89cc9_row11_col14, #T_89cc9_row12_col0, #T_89cc9_row12_col1, #T_89cc9_row12_col2, #T_89cc9_row12_col3, #T_89cc9_row12_col4, #T_89cc9_row12_col5, #T_89cc9_row12_col6, #T_89cc9_row12_col7, #T_89cc9_row12_col8, #T_89cc9_row12_col9, #T_89cc9_row12_col10, #T_89cc9_row12_col11, #T_89cc9_row12_col12, #T_89cc9_row12_col14, #T_89cc9_row13_col0, #T_89cc9_row13_col1, #T_89cc9_row13_col2, #T_89cc9_row13_col3, #T_89cc9_row13_col4, #T_89cc9_row13_col5, #T_89cc9_row13_col6, #T_89cc9_row13_col7, #T_89cc9_row13_col8, #T_89cc9_row13_col9, #T_89cc9_row13_col10, #T_89cc9_row13_col11, #T_89cc9_row13_col12, #T_89cc9_row13_col14, #T_89cc9_row14_col0, #T_89cc9_row14_col1, #T_89cc9_row14_col2, #T_89cc9_row14_col3, #T_89cc9_row14_col4, #T_89cc9_row14_col5, #T_89cc9_row14_col6, #T_89cc9_row14_col7, #T_89cc9_row14_col8, #T_89cc9_row14_col9, #T_89cc9_row14_col10, #T_89cc9_row14_col11, #T_89cc9_row14_col12, #T_89cc9_row14_col14, #T_89cc9_row15_col0, #T_89cc9_row15_col1, #T_89cc9_row15_col2, #T_89cc9_row15_col3, #T_89cc9_row15_col4, #T_89cc9_row15_col5, #T_89cc9_row15_col6, #T_89cc9_row15_col7, #T_89cc9_row15_col8, #T_89cc9_row15_col9, #T_89cc9_row15_col10, #T_89cc9_row15_col11, #T_89cc9_row15_col12, #T_89cc9_row15_col14, #T_89cc9_row16_col0, #T_89cc9_row16_col1, #T_89cc9_row16_col2, #T_89cc9_row16_col3, #T_89cc9_row16_col4, #T_89cc9_row16_col5, #T_89cc9_row16_col6, #T_89cc9_row16_col7, #T_89cc9_row16_col8, #T_89cc9_row16_col9, #T_89cc9_row16_col10, #T_89cc9_row16_col11, #T_89cc9_row16_col12, #T_89cc9_row16_col14, #T_89cc9_row17_col0, #T_89cc9_row17_col1, #T_89cc9_row17_col2, #T_89cc9_row17_col3, #T_89cc9_row17_col4, #T_89cc9_row17_col5, #T_89cc9_row17_col6, #T_89cc9_row17_col7, #T_89cc9_row17_col8, #T_89cc9_row17_col9, #T_89cc9_row17 ...
# Метрики качества модели:
# Accuracy (Точность): 91.87%
# Precision (Точность по положительному классу): 88.06%
# Recall (Полнота): 96.72%
# F1-score (F-мера): 92.19%
# ROC AUC: 97.90%
# Log Loss: 0.1947
#
# Матрица ошибок (Confusion Matrix):
# True Negative: 54 (Правильно предсказанные победы второго игрока)
# False Positive: 8 (Неправильно предсказанные победы первого игрока)
# False Negative: 2 (Неправильно предсказанные победы второго игрока)
# True Positive: 59 (Правильно предсказанные победы первого игрока)
#
# Точность предсказаний по уровню уверенности:
# Уверенность 50%-60%: 80.00% точность (5 матчей)
# Уверенность 60%-70%: 62.50% точность (8 матчей)
# Уверенность 70%-80%: 66.67% точность (15 матчей)
# Уверенность 80%-90%: 90.91% точность (11 матчей)
# Уверенность 90%-100%: 100.00% точность (84 матчей)
#
# Важность признаков:
#            Feature  Importance
# 11      sets_won_1      0.3455
# 12      sets_won_2      0.3090
# 4            Odd_1      0.1095
# 3            Pts_2      0.0560
# 0           Rank_1      0.0511
# 16  rank_advantage      0.0365
# 13   total_games_1      0.0292
# 2            Pts_1      0.0146
# 14   total_games_2      0.0146
# 5            Odd_2      0.0122

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Обучение модели на маленькой выборке с пропущенными значениями

# %%
df_train = pd.read_csv('atp_tennis_47302_xxs.csv')

# Имитируем пропущенные значения в обучающей выборке
df_train_missing = create_realistic_tennis_missing_data(df_train, random_state=32)

# Обучаем модель
model = train_model(df_train_missing)
print(f"Размер тренировочного набора: {len(df_train)}")
# Out:
# Размер тренировочного набора: 50

# %% [markdown]
# ### Тестирование на выборке без пропущенных значений

# %%
df_test = pd.read_csv('atp_tennis_test_minus_1_set_47967_big.csv')

# Получаем предсказания
predictions = get_predictions(model, df_test)
    
# Создаем таблицу результатов
results = create_results_table(df_test, predictions)
    
# Отображаем результаты
display_results(results)
    
# Отображаем подробные метрики качества модели
display_metrics(model, df_test, predictions, results)
# Out:
# <style type="text/css">
# #T_aa085_row0_col0, #T_aa085_row0_col1, #T_aa085_row0_col2, #T_aa085_row0_col3, #T_aa085_row0_col4, #T_aa085_row0_col5, #T_aa085_row0_col6, #T_aa085_row0_col7, #T_aa085_row0_col8, #T_aa085_row0_col9, #T_aa085_row0_col10, #T_aa085_row0_col11, #T_aa085_row0_col12, #T_aa085_row0_col14, #T_aa085_row1_col0, #T_aa085_row1_col1, #T_aa085_row1_col2, #T_aa085_row1_col3, #T_aa085_row1_col4, #T_aa085_row1_col5, #T_aa085_row1_col6, #T_aa085_row1_col7, #T_aa085_row1_col8, #T_aa085_row1_col9, #T_aa085_row1_col10, #T_aa085_row1_col11, #T_aa085_row1_col12, #T_aa085_row1_col14, #T_aa085_row3_col0, #T_aa085_row3_col1, #T_aa085_row3_col2, #T_aa085_row3_col3, #T_aa085_row3_col4, #T_aa085_row3_col5, #T_aa085_row3_col6, #T_aa085_row3_col7, #T_aa085_row3_col8, #T_aa085_row3_col9, #T_aa085_row3_col10, #T_aa085_row3_col11, #T_aa085_row3_col12, #T_aa085_row3_col14, #T_aa085_row4_col0, #T_aa085_row4_col1, #T_aa085_row4_col2, #T_aa085_row4_col3, #T_aa085_row4_col4, #T_aa085_row4_col5, #T_aa085_row4_col6, #T_aa085_row4_col7, #T_aa085_row4_col8, #T_aa085_row4_col9, #T_aa085_row4_col10, #T_aa085_row4_col11, #T_aa085_row4_col12, #T_aa085_row4_col14, #T_aa085_row5_col0, #T_aa085_row5_col1, #T_aa085_row5_col2, #T_aa085_row5_col3, #T_aa085_row5_col4, #T_aa085_row5_col5, #T_aa085_row5_col6, #T_aa085_row5_col7, #T_aa085_row5_col8, #T_aa085_row5_col9, #T_aa085_row5_col10, #T_aa085_row5_col11, #T_aa085_row5_col12, #T_aa085_row5_col14, #T_aa085_row6_col0, #T_aa085_row6_col1, #T_aa085_row6_col2, #T_aa085_row6_col3, #T_aa085_row6_col4, #T_aa085_row6_col5, #T_aa085_row6_col6, #T_aa085_row6_col7, #T_aa085_row6_col8, #T_aa085_row6_col9, #T_aa085_row6_col10, #T_aa085_row6_col11, #T_aa085_row6_col12, #T_aa085_row6_col14, #T_aa085_row7_col0, #T_aa085_row7_col1, #T_aa085_row7_col2, #T_aa085_row7_col3, #T_aa085_row7_col4, #T_aa085_row7_col5, #T_aa085_row7_col6, #T_aa085_row7_col7, #T_aa085_row7_col8, #T_aa085_row7_col9, #T_aa085_row7_col10, #T_aa085_row7_col11, #T_aa085_row7_col12, #T_aa085_row7_col14, #T_aa085_row10_col0, #T_aa085_row10_col1, #T_aa085_row10_col2, #T_aa085_row10_col3, #T_aa085_row10_col4, #T_aa085_row10_col5, #T_aa085_row10_col6, #T_aa085_row10_col7, #T_aa085_row10_col8, #T_aa085_row10_col9, #T_aa085_row10_col10, #T_aa085_row10_col11, #T_aa085_row10_col12, #T_aa085_row10_col14, #T_aa085_row11_col0, #T_aa085_row11_col1, #T_aa085_row11_col2, #T_aa085_row11_col3, #T_aa085_row11_col4, #T_aa085_row11_col5, #T_aa085_row11_col6, #T_aa085_row11_col7, #T_aa085_row11_col8, #T_aa085_row11_col9, #T_aa085_row11_col10, #T_aa085_row11_col11, #T_aa085_row11_col12, #T_aa085_row11_col14, #T_aa085_row12_col0, #T_aa085_row12_col1, #T_aa085_row12_col2, #T_aa085_row12_col3, #T_aa085_row12_col4, #T_aa085_row12_col5, #T_aa085_row12_col6, #T_aa085_row12_col7, #T_aa085_row12_col8, #T_aa085_row12_col9, #T_aa085_row12_col10, #T_aa085_row12_col11, #T_aa085_row12_col12, #T_aa085_row12_col14, #T_aa085_row13_col0, #T_aa085_row13_col1, #T_aa085_row13_col2, #T_aa085_row13_col3, #T_aa085_row13_col4, #T_aa085_row13_col5, #T_aa085_row13_col6, #T_aa085_row13_col7, #T_aa085_row13_col8, #T_aa085_row13_col9, #T_aa085_row13_col10, #T_aa085_row13_col11, #T_aa085_row13_col12, #T_aa085_row13_col14, #T_aa085_row14_col0, #T_aa085_row14_col1, #T_aa085_row14_col2, #T_aa085_row14_col3, #T_aa085_row14_col4, #T_aa085_row14_col5, #T_aa085_row14_col6, #T_aa085_row14_col7, #T_aa085_row14_col8, #T_aa085_row14_col9, #T_aa085_row14_col10, #T_aa085_row14_col11, #T_aa085_row14_col12, #T_aa085_row14_col14, #T_aa085_row15_col0, #T_aa085_row15_col1, #T_aa085_row15_col2, #T_aa085_row15_col3, #T_aa085_row15_col4, #T_aa085_row15_col5, #T_aa085_row15_col6, #T_aa085_row15_col7, #T_aa085_row15_col8, #T_aa085_row15_col9, #T_aa085_row15_col10, #T_aa085_row15_col11, #T_aa085_row15_col12, #T_aa085_row15_col14, #T_aa085_row16_col0, #T_aa085_row16_col1, #T_aa085_row16_col2, #T_aa085_row16_col3, #T_aa085_row16_col4, #T_aa085_row16_col5, #T_aa085_row16_col6, #T_aa085_row16_col7, #T_aa085_row16_col8, #T_aa085_row16_col9, #T_aa085_row16 ...
# Метрики качества модели:
# Accuracy (Точность): 91.87%
# Precision (Точность по положительному классу): 91.80%
# Recall (Полнота): 91.80%
# F1-score (F-мера): 91.80%
# ROC AUC: 97.83%
# Log Loss: 0.2005
#
# Матрица ошибок (Confusion Matrix):
# True Negative: 57 (Правильно предсказанные победы второго игрока)
# False Positive: 5 (Неправильно предсказанные победы первого игрока)
# False Negative: 5 (Неправильно предсказанные победы второго игрока)
# True Positive: 56 (Правильно предсказанные победы первого игрока)
#
# Точность предсказаний по уровню уверенности:
# Уверенность 50%-60%: 83.33% точность (6 матчей)
# Уверенность 60%-70%: 54.55% точность (11 матчей)
# Уверенность 70%-80%: 90.91% точность (11 матчей)
# Уверенность 80%-90%: 72.73% точность (11 матчей)
# Уверенность 90%-100%: 100.00% точность (84 матчей)
#
# Важность признаков:
#                     Feature  Importance
# 11               sets_won_1      0.2891
# 12               sets_won_2      0.2587
# 13            total_games_1      0.1043
# 18           odds_advantage      0.0717
# 0                    Rank_1      0.0717
# 23  rank_points_interaction      0.0587
# 4                     Odd_1      0.0435
# 14            total_games_2      0.0413
# 1                    Rank_2      0.0239
# 17         points_advantage      0.0152

# %% [markdown]
# ### Тестирование на выборке с пропущенными значениями

# %%
df_test = pd.read_csv('atp_tennis_test_minus_1_set_47967_big.csv')

# Имитируем пропущенные значения в тестовой выборке
df_test_missing = create_realistic_tennis_missing_data(df_test, random_state=32)

# Получаем предсказания
predictions = get_predictions(model, df_test_missing)
    
# Создаем таблицу результатов
results = create_results_table(df_test_missing, predictions)
    
# Отображаем результаты
display_results(results)
    
# Отображаем подробные метрики качества модели
display_metrics(model, df_test_missing, predictions, results)
# Out:
# <style type="text/css">
# #T_ff789_row0_col0, #T_ff789_row0_col1, #T_ff789_row0_col2, #T_ff789_row0_col3, #T_ff789_row0_col4, #T_ff789_row0_col5, #T_ff789_row0_col6, #T_ff789_row0_col7, #T_ff789_row0_col8, #T_ff789_row0_col9, #T_ff789_row0_col10, #T_ff789_row0_col11, #T_ff789_row0_col12, #T_ff789_row0_col14, #T_ff789_row1_col0, #T_ff789_row1_col1, #T_ff789_row1_col2, #T_ff789_row1_col3, #T_ff789_row1_col4, #T_ff789_row1_col5, #T_ff789_row1_col6, #T_ff789_row1_col7, #T_ff789_row1_col8, #T_ff789_row1_col9, #T_ff789_row1_col10, #T_ff789_row1_col11, #T_ff789_row1_col12, #T_ff789_row1_col14, #T_ff789_row3_col0, #T_ff789_row3_col1, #T_ff789_row3_col2, #T_ff789_row3_col3, #T_ff789_row3_col4, #T_ff789_row3_col5, #T_ff789_row3_col6, #T_ff789_row3_col7, #T_ff789_row3_col8, #T_ff789_row3_col9, #T_ff789_row3_col10, #T_ff789_row3_col11, #T_ff789_row3_col12, #T_ff789_row3_col14, #T_ff789_row4_col0, #T_ff789_row4_col1, #T_ff789_row4_col2, #T_ff789_row4_col3, #T_ff789_row4_col4, #T_ff789_row4_col5, #T_ff789_row4_col6, #T_ff789_row4_col7, #T_ff789_row4_col8, #T_ff789_row4_col9, #T_ff789_row4_col10, #T_ff789_row4_col11, #T_ff789_row4_col12, #T_ff789_row4_col14, #T_ff789_row5_col0, #T_ff789_row5_col1, #T_ff789_row5_col2, #T_ff789_row5_col3, #T_ff789_row5_col4, #T_ff789_row5_col5, #T_ff789_row5_col6, #T_ff789_row5_col7, #T_ff789_row5_col8, #T_ff789_row5_col9, #T_ff789_row5_col10, #T_ff789_row5_col11, #T_ff789_row5_col12, #T_ff789_row5_col14, #T_ff789_row6_col0, #T_ff789_row6_col1, #T_ff789_row6_col2, #T_ff789_row6_col3, #T_ff789_row6_col4, #T_ff789_row6_col5, #T_ff789_row6_col6, #T_ff789_row6_col7, #T_ff789_row6_col8, #T_ff789_row6_col9, #T_ff789_row6_col10, #T_ff789_row6_col11, #T_ff789_row6_col12, #T_ff789_row6_col14, #T_ff789_row10_col0, #T_ff789_row10_col1, #T_ff789_row10_col2, #T_ff789_row10_col3, #T_ff789_row10_col4, #T_ff789_row10_col5, #T_ff789_row10_col6, #T_ff789_row10_col7, #T_ff789_row10_col8, #T_ff789_row10_col9, #T_ff789_row10_col10, #T_ff789_row10_col11, #T_ff789_row10_col12, #T_ff789_row10_col14, #T_ff789_row12_col0, #T_ff789_row12_col1, #T_ff789_row12_col2, #T_ff789_row12_col3, #T_ff789_row12_col4, #T_ff789_row12_col5, #T_ff789_row12_col6, #T_ff789_row12_col7, #T_ff789_row12_col8, #T_ff789_row12_col9, #T_ff789_row12_col10, #T_ff789_row12_col11, #T_ff789_row12_col12, #T_ff789_row12_col14, #T_ff789_row13_col0, #T_ff789_row13_col1, #T_ff789_row13_col2, #T_ff789_row13_col3, #T_ff789_row13_col4, #T_ff789_row13_col5, #T_ff789_row13_col6, #T_ff789_row13_col7, #T_ff789_row13_col8, #T_ff789_row13_col9, #T_ff789_row13_col10, #T_ff789_row13_col11, #T_ff789_row13_col12, #T_ff789_row13_col14, #T_ff789_row14_col0, #T_ff789_row14_col1, #T_ff789_row14_col2, #T_ff789_row14_col3, #T_ff789_row14_col4, #T_ff789_row14_col5, #T_ff789_row14_col6, #T_ff789_row14_col7, #T_ff789_row14_col8, #T_ff789_row14_col9, #T_ff789_row14_col10, #T_ff789_row14_col11, #T_ff789_row14_col12, #T_ff789_row14_col14, #T_ff789_row15_col0, #T_ff789_row15_col1, #T_ff789_row15_col2, #T_ff789_row15_col3, #T_ff789_row15_col4, #T_ff789_row15_col5, #T_ff789_row15_col6, #T_ff789_row15_col7, #T_ff789_row15_col8, #T_ff789_row15_col9, #T_ff789_row15_col10, #T_ff789_row15_col11, #T_ff789_row15_col12, #T_ff789_row15_col14, #T_ff789_row16_col0, #T_ff789_row16_col1, #T_ff789_row16_col2, #T_ff789_row16_col3, #T_ff789_row16_col4, #T_ff789_row16_col5, #T_ff789_row16_col6, #T_ff789_row16_col7, #T_ff789_row16_col8, #T_ff789_row16_col9, #T_ff789_row16_col10, #T_ff789_row16_col11, #T_ff789_row16_col12, #T_ff789_row16_col14, #T_ff789_row17_col0, #T_ff789_row17_col1, #T_ff789_row17_col2, #T_ff789_row17_col3, #T_ff789_row17_col4, #T_ff789_row17_col5, #T_ff789_row17_col6, #T_ff789_row17_col7, #T_ff789_row17_col8, #T_ff789_row17_col9, #T_ff789_row17_col10, #T_ff789_row17_col11, #T_ff789_row17_col12, #T_ff789_row17_col14, #T_ff789_row18_col0, #T_ff789_row18_col1, #T_ff789_row18_col2, #T_ff789_row18_col3, #T_ff789_row18_col4, #T_ff789_row18_col5, #T_ff789_row18_col6, #T_ff789_row18_col7, #T_ff789_row18_col8, #T_ff789_row18_col9,  ...
# Метрики качества модели:
# Accuracy (Точность): 90.24%
# Precision (Точность по положительному классу): 91.53%
# Recall (Полнота): 88.52%
# F1-score (F-мера): 90.00%
# ROC AUC: 97.62%
# Log Loss: 0.2112
#
# Матрица ошибок (Confusion Matrix):
# True Negative: 57 (Правильно предсказанные победы второго игрока)
# False Positive: 5 (Неправильно предсказанные победы первого игрока)
# False Negative: 7 (Неправильно предсказанные победы второго игрока)
# True Positive: 54 (Правильно предсказанные победы первого игрока)
#
# Точность предсказаний по уровню уверенности:
# Уверенность 50%-60%: 62.50% точность (8 матчей)
# Уверенность 60%-70%: 50.00% точность (10 матчей)
# Уверенность 70%-80%: 90.91% точность (11 матчей)
# Уверенность 80%-90%: 72.73% точность (11 матчей)
# Уверенность 90%-100%: 100.00% точность (83 матчей)
#
# Важность признаков:
#                     Feature  Importance
# 11               sets_won_1      0.2891
# 12               sets_won_2      0.2587
# 13            total_games_1      0.1043
# 18           odds_advantage      0.0717
# 0                    Rank_1      0.0717
# 23  rank_points_interaction      0.0587
# 4                     Odd_1      0.0435
# 14            total_games_2      0.0413
# 1                    Rank_2      0.0239
# 17         points_advantage      0.0152
